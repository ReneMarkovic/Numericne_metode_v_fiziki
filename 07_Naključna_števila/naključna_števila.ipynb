# %%
import matplotlib.pyplot as plt

# %% [markdown]
# $$X_{n+1} = (a * X_{n} + c) \mod m $$

# %%
def LCG(X0:int,a:int,c:int,m:int):
    '''
    X0: seme
    a: množitelj (angl. multiplier),
    c: inkrement (angl. increment),
    m: modulo (angl. modulus).
    '''
    return (a*X0+c)%m

def generator(X0,a,c,m,N=1):
    if N==1:
        return LCG(X0,a,c,m)/m
    else:
        sample=[]
        sample.append(X0/m)
        for k in range(N-1):
            X1=LCG(X0,a,c,m)
            X0=X1
            sample.append(X0/m)
        return sample
    
def plot(sample):
    plt.figure(figsize=(21,6))
    plt.subplot(1,3,1)
    plt.plot(sample,'o-')
    plt.xlabel('$n$')
    plt.ylabel('$X_n$')
    
    plt.subplot(1,3,2)
    x=sample[0:-1]
    y=sample[1:]
    plt.scatter(x,y)
    plt.xlabel('$X_n$')
    plt.ylabel('$X_{n+1}$')
    
    plt.subplot(1,3,3)
    plt.hist(sample,bins=20)
    
    plt.show()

# %% [markdown]
# # Primer 1

# %%
a=c=x0=5
m=10

sample=generator(x0,a,c,m,N=10)
print("Sample =",sample)
plot(sample)
# Out:
# Sample = [0.5, 0.0, 0.5, 0.0, 0.5, 0.0, 0.5, 0.0, 0.5, 0.0]

# %% [markdown]
# # Primer 2

# %%
a=19
c=0
x0=5
m=256

sample=generator(x0,a,c,m,N=100)
print("Sample =",sample)
plot(sample)

sample1=generator(x0,a,c,m,N=100)
sample2=generator(x0+1,a,c,m,N=100)
sample3=generator(x0+2,a,c,m,N=100)

plt.title("Vpliv semena na potek vrste")
plt.plot(sample1,'o-',label='sample1')
plt.plot(sample2,'o-',label='sample2')
plt.plot(sample3,'o-',label='sample3')
plt.xlim(0,20)
plt.show()
# Out:
# Sample = [0.01953125, 0.37109375, 0.05078125, 0.96484375, 0.33203125, 0.30859375, 0.86328125, 0.40234375, 0.64453125, 0.24609375, 0.67578125, 0.83984375, 0.95703125, 0.18359375, 0.48828125, 0.27734375, 0.26953125, 0.12109375, 0.30078125, 0.71484375, 0.58203125, 0.05859375, 0.11328125, 0.15234375, 0.89453125, 0.99609375, 0.92578125, 0.58984375, 0.20703125, 0.93359375, 0.73828125, 0.02734375, 0.51953125, 0.87109375, 0.55078125, 0.46484375, 0.83203125, 0.80859375, 0.36328125, 0.90234375, 0.14453125, 0.74609375, 0.17578125, 0.33984375, 0.45703125, 0.68359375, 0.98828125, 0.77734375, 0.76953125, 0.62109375, 0.80078125, 0.21484375, 0.08203125, 0.55859375, 0.61328125, 0.65234375, 0.39453125, 0.49609375, 0.42578125, 0.08984375, 0.70703125, 0.43359375, 0.23828125, 0.52734375, 0.01953125, 0.37109375, 0.05078125, 0.96484375, 0.33203125, 0.30859375, 0.86328125, 0.40234375, 0.64453125, 0.24609375, 0.67578125, 0.83984375, 0.95703125, 0.18359375, 0.48828125, 0.27734375, 0.26953125, 0.12109375, 0.30078125, 0.71484375, 0.58203125, 0.05859375, 0.11328125, 0.15234375, 0.89453125, 0.99609375, 0.92578125, 0.58984375, 0.20703125, 0.93359375, 0.73828125, 0.02734375, 0.51953125, 0.87109375, 0.55078125, 0.46484375]

# %% [markdown]
# # Primer 3

# %%
a=137
c=1
x0=5
m=256

sample=generator(x0,a,c,m,N=100)
print("Sample =",sample)
plot(sample)
# Out:
# Sample = [0.01953125, 0.6796875, 0.12109375, 0.59375, 0.34765625, 0.6328125, 0.69921875, 0.796875, 0.17578125, 0.0859375, 0.77734375, 0.5, 0.50390625, 0.0390625, 0.35546875, 0.703125, 0.33203125, 0.4921875, 0.43359375, 0.40625, 0.66015625, 0.4453125, 0.01171875, 0.609375, 0.48828125, 0.8984375, 0.08984375, 0.3125, 0.81640625, 0.8515625, 0.66796875, 0.515625, 0.64453125, 0.3046875, 0.74609375, 0.21875, 0.97265625, 0.2578125, 0.32421875, 0.421875, 0.80078125, 0.7109375, 0.40234375, 0.125, 0.12890625, 0.6640625, 0.98046875, 0.328125, 0.95703125, 0.1171875, 0.05859375, 0.03125, 0.28515625, 0.0703125, 0.63671875, 0.234375, 0.11328125, 0.5234375, 0.71484375, 0.9375, 0.44140625, 0.4765625, 0.29296875, 0.140625, 0.26953125, 0.9296875, 0.37109375, 0.84375, 0.59765625, 0.8828125, 0.94921875, 0.046875, 0.42578125, 0.3359375, 0.02734375, 0.75, 0.75390625, 0.2890625, 0.60546875, 0.953125, 0.58203125, 0.7421875, 0.68359375, 0.65625, 0.91015625, 0.6953125, 0.26171875, 0.859375, 0.73828125, 0.1484375, 0.33984375, 0.5625, 0.06640625, 0.1015625, 0.91796875, 0.765625, 0.89453125, 0.5546875, 0.99609375, 0.46875]

# %% [markdown]
# # Primer 4

# %%
a=19
c=0
x0=5
m=256

sample=generator(x0,a,c,m,N=100)
print("Sample =",sample)
plot(sample)
# Out:
# Sample = [0.01953125, 0.37109375, 0.05078125, 0.96484375, 0.33203125, 0.30859375, 0.86328125, 0.40234375, 0.64453125, 0.24609375, 0.67578125, 0.83984375, 0.95703125, 0.18359375, 0.48828125, 0.27734375, 0.26953125, 0.12109375, 0.30078125, 0.71484375, 0.58203125, 0.05859375, 0.11328125, 0.15234375, 0.89453125, 0.99609375, 0.92578125, 0.58984375, 0.20703125, 0.93359375, 0.73828125, 0.02734375, 0.51953125, 0.87109375, 0.55078125, 0.46484375, 0.83203125, 0.80859375, 0.36328125, 0.90234375, 0.14453125, 0.74609375, 0.17578125, 0.33984375, 0.45703125, 0.68359375, 0.98828125, 0.77734375, 0.76953125, 0.62109375, 0.80078125, 0.21484375, 0.08203125, 0.55859375, 0.61328125, 0.65234375, 0.39453125, 0.49609375, 0.42578125, 0.08984375, 0.70703125, 0.43359375, 0.23828125, 0.52734375, 0.01953125, 0.37109375, 0.05078125, 0.96484375, 0.33203125, 0.30859375, 0.86328125, 0.40234375, 0.64453125, 0.24609375, 0.67578125, 0.83984375, 0.95703125, 0.18359375, 0.48828125, 0.27734375, 0.26953125, 0.12109375, 0.30078125, 0.71484375, 0.58203125, 0.05859375, 0.11328125, 0.15234375, 0.89453125, 0.99609375, 0.92578125, 0.58984375, 0.20703125, 0.93359375, 0.73828125, 0.02734375, 0.51953125, 0.87109375, 0.55078125, 0.46484375]

# %% [markdown]
# # Primer 5

# %%
a=21
c=0
x0=5
m=256

sample=generator(x0,a,c,m,N=100)
